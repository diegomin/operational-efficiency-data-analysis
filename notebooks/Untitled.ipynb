# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Datos

# %%
orders = pd.DataFrame({
    'order_id': range(1, 101),
    'customer_id': np.random.randint(1, 21, 100),
    'order_date': pd.date_range('2025-01-01', periods=100, freq='D'),
    'delivery_days': np.random.randint(1, 10, 100),
    'cost': np.random.uniform(50, 300, 100),
    'status': np.random.choice(['Entregado', 'Retrasado'], 100, p=[0.8, 0.2])
})
